# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Amazon.csv")
df.head()
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3  ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4  ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
#
#            ProductName        Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini           Books   BrightLux         3     106.59
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03
# 3       Webcam Full HD  Home & Kitchen      Zenith         5      33.58
# 4              T-Shirt        Clothing    KiddoFun         2     515.64
#
#    Discount    Tax  ShippingCost  TotalAmount     PaymentMethod OrderStatus  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderID        100000 non-null  object
#  1   OrderDate      100000 non-null  object
#  2   CustomerID     100000 non-null  object
#  3   CustomerName   100000 non-null  object
#  4   ProductID      100000 non-null  object
#  5   ProductName    100000 non-null  object
#  6   Category       100000 non-null  object
#  7   Brand          100000 non-null  object
#  8   Quantity       100000 non-null  int64
#  9   UnitPrice      100000 non-null  float64
#  10  Discount       100000 non-null  float64
#  11  Tax            100000 non-null  float64
#  12  ShippingCost   100000 non-null  float64
#  13  TotalAmount    100000 non-null  float64
#  14  PaymentMethod  100000 non-null  object
#  15  OrderStatus    100000 non-null  object
#  16  City           100000 non-null  object
# ...

# %% [markdown]
# data cleaning

# %%
df.isnull().sum()
# Out:
# OrderID          0
# OrderDate        0
# CustomerID       0
# CustomerName     0
# ProductID        0
# ProductName      0
# Category         0
# Brand            0
# Quantity         0
# UnitPrice        0
# Discount         0
# Tax              0
# ShippingCost     0
# TotalAmount      0
# PaymentMethod    0
# OrderStatus      0
# City             0
# State            0
# Country          0
# SellerID         0
# dtype: int64

# %%
df.drop(["OrderID","CustomerID","SellerID","ProductID"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     OrderDate   CustomerName          ProductName        Category       Brand  \
# 0  2023-01-31  Vihaan Sharma           Drone Mini           Books   BrightLux
# 1  2023-12-30    Pooja Kumar           Microphone  Home & Kitchen  UrbanStyle
# 2  2022-05-10    Sneha Singh  Power Bank 20000mAh        Clothing  UrbanStyle
# 3  2023-07-18   Vihaan Reddy       Webcam Full HD  Home & Kitchen      Zenith
# 4  2023-02-04  Aditya Kapoor              T-Shirt        Clothing    KiddoFun
#
#    Quantity  UnitPrice  Discount    Tax  ShippingCost  TotalAmount  \
# 0         3     106.59      0.00   0.00          0.09       319.86
# 1         1     251.37      0.05  19.10          1.74       259.64
# 2         3      35.03      0.10   7.57          5.91       108.06
# 3         5      33.58      0.15  11.42          5.53       159.66
# 4         2     515.64      0.25  38.67          9.23       821.36
#
#       PaymentMethod OrderStatus         City State        Country
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# visualization

# %%
df.head()
# Out:
#     OrderDate   CustomerName          ProductName        Category       Brand  \
# 0  2023-01-31  Vihaan Sharma           Drone Mini           Books   BrightLux
# 1  2023-12-30    Pooja Kumar           Microphone  Home & Kitchen  UrbanStyle
# 2  2022-05-10    Sneha Singh  Power Bank 20000mAh        Clothing  UrbanStyle
# 3  2023-07-18   Vihaan Reddy       Webcam Full HD  Home & Kitchen      Zenith
# 4  2023-02-04  Aditya Kapoor              T-Shirt        Clothing    KiddoFun
#
#    Quantity  UnitPrice  Discount    Tax  ShippingCost  TotalAmount  \
# 0         3     106.59      0.00   0.00          0.09       319.86
# 1         1     251.37      0.05  19.10          1.74       259.64
# 2         3      35.03      0.10   7.57          5.91       108.06
# 3         5      33.58      0.15  11.42          5.53       159.66
# 4         2     515.64      0.25  38.67          9.23       821.36
#
#       PaymentMethod OrderStatus         City State        Country
# ...

# %%
plt.hist(df["OrderStatus"])
# Out:
# (array([74628.,     0.,  3028.,     0.,     0.,  4103.,     0., 15192.,
#             0.,  3049.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(data=df,x="PaymentMethod",hue="OrderStatus")
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='count'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# correlation analysis

# %%
df.head()
# Out:
#     OrderDate   CustomerName          ProductName        Category       Brand  \
# 0  2023-01-31  Vihaan Sharma           Drone Mini           Books   BrightLux
# 1  2023-12-30    Pooja Kumar           Microphone  Home & Kitchen  UrbanStyle
# 2  2022-05-10    Sneha Singh  Power Bank 20000mAh        Clothing  UrbanStyle
# 3  2023-07-18   Vihaan Reddy       Webcam Full HD  Home & Kitchen      Zenith
# 4  2023-02-04  Aditya Kapoor              T-Shirt        Clothing    KiddoFun
#
#    Quantity  UnitPrice  Discount    Tax  ShippingCost  TotalAmount  \
# 0         3     106.59      0.00   0.00          0.09       319.86
# 1         1     251.37      0.05  19.10          1.74       259.64
# 2         3      35.03      0.10   7.57          5.91       108.06
# 3         5      33.58      0.15  11.42          5.53       159.66
# 4         2     515.64      0.25  38.67          9.23       821.36
#
#       PaymentMethod OrderStatus         City State        Country
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["CustomerName"]=le.fit_transform(df["CustomerName"])
df["ProductName"]=le.fit_transform(df["ProductName"])
df["Category"]=le.fit_transform(df["Category"])
df["Brand"]=le.fit_transform(df["Brand"])
df["PaymentMethod"]=le.fit_transform(df["PaymentMethod"])
df["City"]=le.fit_transform(df["City"])
df["State"]=le.fit_transform(df["State"])
df["Country"]=le.fit_transform(df["Country"])
df.head()
# Out:
#     OrderDate  CustomerName  ProductName  Category  Brand  Quantity  \
# 0  2023-01-31           177           12         0      1         3
# 1  2023-12-30            93           26         3      8         1
# 2  2022-05-10           158           32         1      8         3
# 3  2023-07-18           176           45         3      9         5
# 4  2023-02-04            12           41         1      5         2
#
#    UnitPrice  Discount    Tax  ShippingCost  TotalAmount  PaymentMethod  \
# 0     106.59      0.00   0.00          0.09       319.86              3
# 1     251.37      0.05  19.10          1.74       259.64              0
# 2      35.03      0.10   7.57          5.91       108.06              3
# 3      33.58      0.15  11.42          5.53       159.66              1
# 4     515.64      0.25  38.67          9.23       821.36              2
#
#   OrderStatus  City  State  Country
# 0   Delivered    19      3        2
# 1   Delivered     6     11        4
# ...

# %%
df.replace({
    "Pending":1,
    "Processing":2,
    "Shipped":3,
    "Out for Delivery":4,
    "Delivered":5,
    "Returned":6,
    "Cancelled":7
},inplace=True)
# Out:
# /tmp/ipython-input-3068178932.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({

# %%
df
# Out:
#         OrderDate  CustomerName  ProductName  Category  Brand  Quantity  \
# 0      2023-01-31           177           12         0      1         3
# 1      2023-12-30            93           26         3      8         1
# 2      2022-05-10           158           32         1      8         3
# 3      2023-07-18           176           45         3      9         5
# 4      2023-02-04            12           41         1      5         2
# ...           ...           ...          ...       ...    ...       ...
# 99995  2023-03-07            61           25         2      0         2
# 99996  2021-11-24           162            6         4      0         5
# 99997  2023-04-29            20           11         4      1         4
# 99998  2021-11-01           140            6         4      4         1
# 99999  2021-12-04           166           22         3      2         5
#
#        UnitPrice  Discount     Tax  ShippingCost  TotalAmount  PaymentMethod  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderDate      100000 non-null  object
#  1   CustomerName   100000 non-null  int64
#  2   ProductName    100000 non-null  int64
#  3   Category       100000 non-null  int64
#  4   Brand          100000 non-null  int64
#  5   Quantity       100000 non-null  int64
#  6   UnitPrice      100000 non-null  float64
#  7   Discount       100000 non-null  float64
#  8   Tax            100000 non-null  float64
#  9   ShippingCost   100000 non-null  float64
#  10  TotalAmount    100000 non-null  float64
#  11  PaymentMethod  100000 non-null  int64
#  12  OrderStatus    100000 non-null  int64
#  13  City           100000 non-null  int64
#  14  State          100000 non-null  int64
#  15  Country        100000 non-null  int64
# dtypes: float64(5), int64(10), object(1)
# ...

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'])

# %%
df["OrderDate"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderDate      100000 non-null  datetime64[ns]
#  1   CustomerName   100000 non-null  int64
#  2   ProductName    100000 non-null  int64
#  3   Category       100000 non-null  int64
#  4   Brand          100000 non-null  int64
#  5   Quantity       100000 non-null  int64
#  6   UnitPrice      100000 non-null  float64
#  7   Discount       100000 non-null  float64
#  8   Tax            100000 non-null  float64
#  9   ShippingCost   100000 non-null  float64
#  10  TotalAmount    100000 non-null  float64
#  11  PaymentMethod  100000 non-null  int64
#  12  OrderStatus    100000 non-null  int64
#  13  City           100000 non-null  int64
#  14  State          100000 non-null  int64
#  15  Country        100000 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(10)
# ...

# %%
df.head()
# Out:
#    OrderDate  CustomerName  ProductName  Category  Brand  Quantity  UnitPrice  \
# 0 2023-01-31           177           12         0      1         3     106.59
# 1 2023-12-30            93           26         3      8         1     251.37
# 2 2022-05-10           158           32         1      8         3      35.03
# 3 2023-07-18           176           45         3      9         5      33.58
# 4 2023-02-04            12           41         1      5         2     515.64
#
#    Discount    Tax  ShippingCost  TotalAmount  PaymentMethod  OrderStatus  \
# 0      0.00   0.00          0.09       319.86              3            5
# 1      0.05  19.10          1.74       259.64              0            5
# 2      0.10   7.57          5.91       108.06              3            5
# 3      0.15  11.42          5.53       159.66              1            5
# 4      0.25  38.67          9.23       821.36              2            7
#
#    City  State  Country
# 0    19      3        2
# ...

# %% [markdown]
# feature engineering

# %%
df["day"]=df["OrderDate"].dt.day
df["month"]=df["OrderDate"].dt.month
df["year"]=df["OrderDate"].dt.year

# %%
df.drop("OrderDate",axis=1,inplace=True)

# %%
df.head()
# Out:
#    CustomerName  ProductName  Category  Brand  Quantity  UnitPrice  Discount  \
# 0           177           12         0      1         3     106.59      0.00
# 1            93           26         3      8         1     251.37      0.05
# 2           158           32         1      8         3      35.03      0.10
# 3           176           45         3      9         5      33.58      0.15
# 4            12           41         1      5         2     515.64      0.25
#
#      Tax  ShippingCost  TotalAmount  PaymentMethod  OrderStatus  City  State  \
# 0   0.00          0.09       319.86              3            5    19      3
# 1  19.10          1.74       259.64              0            5     6     11
# 2   7.57          5.91       108.06              3            5     0     11
# 3  11.42          5.53       159.66              1            5     1      7
# 4  38.67          9.23       821.36              2            7    14     11
#
#    Country  day  month  year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   CustomerName   100000 non-null  int64
#  1   ProductName    100000 non-null  int64
#  2   Category       100000 non-null  int64
#  3   Brand          100000 non-null  int64
#  4   Quantity       100000 non-null  int64
#  5   UnitPrice      100000 non-null  float64
#  6   Discount       100000 non-null  float64
#  7   Tax            100000 non-null  float64
#  8   ShippingCost   100000 non-null  float64
#  9   TotalAmount    100000 non-null  float64
#  10  PaymentMethod  100000 non-null  int64
#  11  OrderStatus    100000 non-null  int64
#  12  City           100000 non-null  int64
#  13  State          100000 non-null  int64
#  14  Country        100000 non-null  int64
#  15  day            100000 non-null  int32
#  16  month          100000 non-null  int32
# ...

# %%
corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True,fmt='0.1f',cmap='coolwarm')
plt.title("corr rel matrix")
plt.show()

# %%
TotalAmount_corr_matrix=df.corr()["TotalAmount"]
TotalAmount_corr_matrix=TotalAmount_corr_matrix.drop("TotalAmount")
sns.heatmap(TotalAmount_corr_matrix.to_frame(),annot=True,annot_kws={'size':10},fmt='0.2f',cmap="coolwarm")
plt.title("corr matrix of TotalAmount")
plt.show()

# %%
df.drop(['CustomerName','ProductName','Category','Brand','PaymentMethod','OrderStatus','City','State','Country','day','month','year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Quantity  UnitPrice  Discount    Tax  ShippingCost  TotalAmount
# 0         3     106.59      0.00   0.00          0.09       319.86
# 1         1     251.37      0.05  19.10          1.74       259.64
# 2         3      35.03      0.10   7.57          5.91       108.06
# 3         5      33.58      0.15  11.42          5.53       159.66
# 4         2     515.64      0.25  38.67          9.23       821.36

# %% [markdown]
# outlier

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def out_liers(df,excludecolumn):
  for col in df.columns:
    if col==excludecolumn:
      continue
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    IQR=q3-q1
    lower_bound=q1-1.5*IQR
    upper_bound=q3+1.5*IQR
    df=df[(df[col]<=upper_bound)&(df[col]>=lower_bound)]
  return df

df_cleaned=out_liers(df,excludecolumn="TotalAmount")
df=df_cleaned

# %% [markdown]
# scaling

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

features = ['Quantity',	'UnitPrice',	'Discount',	'Tax',	'ShippingCost']

scaler=MinMaxScaler()

scaled_data=scaler.fit_transform(df[features])

scaled_df=pd.DataFrame(scaled_data,columns=features)

# %% [markdown]
# predict

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
import pandas as pd

X = df[['Quantity',	'UnitPrice',	'Discount',	'Tax',	'ShippingCost']]
y = df['TotalAmount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)


model = LinearRegression()
model.fit(X_train, y_train)


y_pred=model.predict(X_test)
model.score(X_test,y_test)
# Out:
# 0.889675506296546
