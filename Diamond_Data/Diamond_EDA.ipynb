# %% [markdown]
# # **1.load and inspect data**

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=sns.load_dataset("diamonds")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %% [markdown]
# price is the target

# %% [markdown]
# # **Understand the datatype and summary**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %% [markdown]
# ## **Data cleaning**

# %% [markdown]
# in this dataset there is no unwanted columns

# %% [markdown]
# **check null values**

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# check if there exists duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(146)

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (53794, 10)

# %% [markdown]
# # **Visualization**

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
plt.hist(df["cut"])
plt.show()

# %%
sns.countplot(data=df,x="clarity",hue="cut")
plt.show()

# %%
x=df["carat"]
plt.hist(x)
plt.show()

# %%
plt.scatter(df["carat"],df["price"])
plt.show()

# %% [markdown]
# # **Correlation analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53794 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53794 non-null  float64
#  1   cut      53794 non-null  category
#  2   color    53794 non-null  category
#  3   clarity  53794 non-null  category
#  4   depth    53794 non-null  float64
#  5   table    53794 non-null  float64
#  6   price    53794 non-null  int64
#  7   x        53794 non-null  float64
#  8   y        53794 non-null  float64
#  9   z        53794 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.4 MB

# %% [markdown]
# convert all categorical values into numeric value

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53794 rows x 10 columns]

# %% [markdown]
# here all the datas are ordinal so we want to replace

# %%
df["cut"]=df["cut"].replace(["Fair","Good","Very Good","Premium","Ideal"],[1,2,3,4,5])
# Out:
# /tmp/ipython-input-2112924093.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["cut"]=df["cut"].replace(["Fair","Good","Very Good","Premium","Ideal"],[1,2,3,4,5])
# /tmp/ipython-input-2112924093.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df["cut"]=df["cut"].replace(["Fair","Good","Very Good","Premium","Ideal"],[1,2,3,4,5])

# %%
df["color"]=df["color"].replace(["D", "E", "F", "G", "H", "I", "J"],[1,2,3,4,5,6,7])
# Out:
# /tmp/ipython-input-4112062456.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["color"]=df["color"].replace(["D", "E", "F", "G", "H", "I", "J"],[1,2,3,4,5,6,7])
# /tmp/ipython-input-4112062456.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df["color"]=df["color"].replace(["D", "E", "F", "G", "H", "I", "J"],[1,2,3,4,5,6,7])

# %%
df["color"]=df["color"].astype(int)
df["clarity"]=df["clarity"].astype(int)

# %%
df["clarity"]=df["clarity"].replace(["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"],[1,2,3,4,5,6,7,8])
# Out:
# /tmp/ipython-input-2777081539.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["clarity"]=df["clarity"].replace(["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"],[1,2,3,4,5,6,7,8])
# /tmp/ipython-input-2777081539.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df["clarity"]=df["clarity"].replace(["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"],[1,2,3,4,5,6,7,8])

# %%
df
# Out:
#        carat cut color clarity  depth  table  price     x     y     z
# 0       0.23   5     2       2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   4     2       3   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   2     2       5   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   4     6       4   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   2     7       2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ..   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   5     1       3   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   2     1       3   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   3     1       3   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   4     5       2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   5     1       2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53794 rows x 10 columns]

# %% [markdown]
# check correlation

# %%
corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True,fmt='0.1f',cmap="coolwarm")
plt.title("corelation matrix")
plt.show()

# %% [markdown]
# **multicollinearity**(carat,x,y,z)

# %% [markdown]
# take one column and remove remaining

# %%
df.drop(['x','y','z'],axis=1,inplace=True)

# %% [markdown]
# correlartion between price and all other features

# %%
price_corr=df.corr()["price"]
price_corr=price_corr.drop("price")
sns.heatmap(price_corr.to_frame(),annot=True,fmt='0.2f',cmap='coolwarm',annot_kws={'size':10})
plt.title("correlation between price and other features")
plt.show()

# %% [markdown]
# remove less correlated

# %%
df.drop(["cut","depth"],axis=1,inplace=True)

# %% [markdown]
# # **Outlier checking and removing**

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# remove outlier of carat and table

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53794 entries, 0 to 53939
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53794 non-null  float64
#  1   color    53794 non-null  int64
#  2   clarity  53794 non-null  int64
#  3   table    53794 non-null  float64
#  4   price    53794 non-null  int64
# dtypes: float64(2), int64(3)
# memory usage: 2.5 MB

# %%
def rem_outliers_iqr(df,exclude_column):
  for col in df.columns:
    if col==exclude_column:
      continue
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    IQR=q3-q1
    lower_bound = q1 - 1.5 * IQR
    upper_bound = q3 + 1.5 * IQR
     # Filter the DataFrame to remove rows with outliers in each column
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
  return df

df_cleaned=rem_outliers_iqr(df,exclude_column="price")
df=df_cleaned

# %%
df.shape
# Out:
# (51353, 5)

# %% [markdown]
# ## **datascaling**

# %%
df
# Out:
#        carat  color  clarity  table  price
# 0       0.23      2        2   55.0    326
# 1       0.21      2        3   61.0    326
# 3       0.29      6        4   58.0    334
# 4       0.31      7        2   58.0    335
# 5       0.24      7        6   57.0    336
# ...      ...    ...      ...    ...    ...
# 53935   0.72      1        3   57.0   2757
# 53936   0.72      1        3   55.0   2757
# 53937   0.70      1        3   60.0   2757
# 53938   0.86      5        2   58.0   2757
# 53939   0.75      1        2   55.0   2757
#
# [51353 rows x 5 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

features=['carat',	'color'	,'clarity',	'table']
scaler=MinMaxScaler()
scaled_data=scaler.fit_transform(df[features])
scaled_df=pd.DataFrame(scaled_data,columns=features)

# %% [markdown]
# # **After EDA we can predict**

# %% [markdown]
# use linear regression because the data is regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
import pandas as pd

x=df[['carat','color','clarity','table']]
y=df['price']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

model=LinearRegression()
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
model.score(x_test,y_test)
# Out:
# 0.8923752907533311
